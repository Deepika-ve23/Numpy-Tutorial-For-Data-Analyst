# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.4.3

# %%
## Creating Arrays

# %%
list1 = [1,2,3]
print(list1)
# Out:
# [1, 2, 3]

# %%
arr_list1 = np.array(list1)
print(arr_list1)
# Out:
# [1 2 3]

# %%
print(type(arr_list1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr_list1.ndim)
# Out:
# 1

# %%
list1 = [1,2,3]
list2 = [4,5,6]
arr_list1_2 = np.array([list1  ,list2])
print(arr_list1_2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr_list1_2.ndim)
# Out:
# 2

# %%
list1 = [1,2,3]
list2 = [4,5,6]
list3 = [7,8,9]
arr_list1_3 = np.array([[list1  ,list2,list3]])
print(arr_list1_3)
# Out:
# [[[1 2 3]
#   [4 5 6]
#   [7 8 9]]]

# %%
print(arr_list1_3.ndim)
# Out:
# 3

# %%
## numpy array attribute

# %%
arr1 = np.array([[1,2,3] , [4,5,6]])
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print("Shape" , arr1.shape)
print("Size" , arr1.size)
print("dType" , arr1.dtype)
print("n_dim" ,arr1.ndim)
# Out:
# Shape (2, 3)
# Size 6
# dType int64
# n_dim 2

# %%
## Array Initialization method

# %%
#zeros Array
zero_arr = np.zeros((2,3))
print(zero_arr )
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
## one array
one_arr = np.ones((1,3))
print(one_arr)
# Out:
# [[1. 1. 1.]]

# %%
## full array
full_arr = np.full((3,2),8)
print(full_arr)
# Out:
# [[8 8]
#  [8 8]
#  [8 8]]

# %%
id_arr =np.eye(3)
print(id_arr)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
## identify matrix 3 rows 3 colomn

id_arr = np.eye(3)
print(id_arr)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
##empty array
print(np.empty(2))
# Out:
# [9.9e-324 1.5e-323]

# %%
## Evenly Spaced Array
print(np.arange(1,10,2))
# Out:
# [1 3 5 7 9]

# %% [markdown]
# ## Specefic Number of Equally (Speed) value between a range

# %%
print (np.linspace(1,10,4))
# Out:
# [ 1.  4.  7. 10.]

# %%
## random value array Float
r_arr = np.random.rand(3,2)
print(r_arr)
# Out:
# [[0.75468847 0.11677354]
#  [0.77300472 0.11008199]
#  [0.89082376 0.73782703]]

# %%
## random value array int
rint_arr = np.random.randint(1,10,(3,3))
print(rint_arr)
# Out:
# [[3 1 9]
#  [8 8 8]
#  [1 6 5]]

# %%
#Array indexing and Slicing
a= np.array([1,2,3,4,5] )
print(a)
# Out:
# [1 2 3 4 5]

# %%
print(a[0])
# Out:
# 1

# %%
print(a[1])
# Out:
# 2

# %%
print(a[-1])
# Out:
# 5

# %%
#Array indexing and Slicing
a= np.array([1,2,3,4,5] )
print(a)
# slicing [start: stop : stpe]
# stop  # input , that is not include in output
# Out:
# [1 2 3 4 5]

# %%
print(a[0:3])   # first three element
# Out:
# [1 2 3]

# %%
print(a[-5:])
# Out:
# [1 2 3 4 5]

# %%
print(a[0:5:2]) # middle first element with steps
# Out:
# [1 3 5]

# %%
print(a[-3:])   # last  three element
# Out:
# [3 4 5]

# %%
print(a[-3:])
# Out:
# [3 4 5]

# %%
# Two dimention array
arr2 = np.array([[1,2,3] ,[4,5,6]])
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr2[1][1])
# Out:
# 5

# %%
print(arr2[1:])
# Out:
# [[4 5 6]]

# %%
print(arr2[1])
# Out:
# [4 5 6]

# %%
print(arr2[: ,2])
# Out:
# [3 6]

# %%
print(arr2[1][1])
# Out:
# 5

# %%
print(arr2[: , 1])
# 2D : [Rows , columns]
# 3D : [Layers/Height , rows , columns]
# Out:
# [2 5]

# %%
print(arr2[0][0]) # elemnet of first rows first columns
print(arr2[0][1])# elemnet of first rows second columns
print(arr2[0][2])# elemnet of first rows third columns
# Out:
# 1
# 2
# 3

# %%
print(arr2[0] )
print(arr2[1] )
# Out:
# [1 2 3]
# [4 5 6]

# %%
arr3 = np.array([[1,2,3],
                 [2,3,4],
                 [5,6,7]])
print(arr3)
# Out:
# [[1 2 3]
#  [2 3 4]
#  [5 6 7]]

# %%
print (arr3[0])
print (arr3[1])
print (arr3[2])
# Out:
# [1 2 3]
# [2 3 4]
# [5 6 7]

# %%
print(arr3[0][1])
print(arr3[0][2])
print(arr3[0][0])
# Out:
# 2
# 3
# 1

# %%
print(arr3[ : , 2])
# Out:
# [3 4 7]

# %%
print(arr3[ : , 1])
# Out:
# [2 3 6]

# %%
print(arr3[ : , 0])
# Out:
# [1 2 5]

# %%
print(arr3 [::2,0])
# Out:
# [1 5]

# %%
print(arr3 [::3,0])
# Out:
# [1]

# %%
print(arr3[1:2, :1])
# Out:
# [[2]]

# %% [markdown]
# # Array Reshapping and  Flattening

# %%
arr1 = np.array([1,2,3,4,5,6])
print(arr1)
# Out:
# [1 2 3 4 5 6]

# %%
reshape = arr1.reshape([6,1])
print(reshape)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]]

# %%
reshaped1 = arr1.reshape([2,3])
print(reshaped1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
reshaped2 = arr1.reshape([2 ,3])
print(reshaped2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print (reshaped2.flatten())
# Out:
# [1 2 3 4 5 6]

# %%
print(reshaped2.flatten())
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# #Array Stacking and Spliting

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])
print(np.vstack((a,b))) # Verticle stackning in row
print(np.hstack((a,b))) # verticle stacking in columns
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]

# %%
c = np.array([[1,2,3] , [4,5,6]])
print(c)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(np.hsplit(c ,3))
# Out:
# [array([[1],
#        [4]]), array([[2],
#        [5]]), array([[3],
#        [6]])]

# %%
print(np.hsplit(c ,3))
# Out:
# [array([[1],
#        [4]]), array([[2],
#        [5]]), array([[3],
#        [6]])]

# %%
c = np.array([[1,2,3] ,[4,5,6]])
print(c)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# split = np.hsplit(c , 3) # Horizontal split
#
#  for s in vsplit:
#    print(s)

# %%
#Mathematical Operation an Array

# %%
a = np.array([10 , 30 , 50 , -30])
print(a)
# Out:
# [ 10  30  50 -30]

# %%
print(a+10)
print(a-30)
print(a*2)
print(a/10)
# Out:
# [ 20  40  60 -20]
# [-20   0  20 -60]
# [ 20  60 100 -60]
# [ 1.  3.  5. -3.]

# %%
a = np.array([1,4,9])
print(a)
# Out:
# [1 4 9]

# %%
print(np.square(a))
print(np.sqrt(a))
# Out:
# [ 1 16 81]
# [1. 2. 3.]

# %%
# sin , cos, tan , sec

# %%
print(np.sin(a))
print(np.cos(a))
print(np.tan(a))
# Out:
# [ 0.84147098 -0.7568025   0.41211849]
# [ 0.54030231 -0.65364362 -0.91113026]
# [ 1.55740772  1.15782128 -0.45231566]

# %%
#Mathematically Oepration in multiple array

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])
print(a)
print(b)
# Out:
# [1 2 3]
# [4 5 6]

# %%
print(np.add(a ,b))
print(np.subtract(a ,b))
print(np.divide(a ,b))
print(np.multiply(a ,b))
# Out:
# [5 7 9]
# [-3 -3 -3]
# [0.25 0.4  0.5 ]
# [ 4 10 18]

# %%
print(np.dot(a,b))
# Out:
# 32

# %%
print(a.T)
# Out:
# [1 2 3]

# %%
t = np.array([[1,2,3],
              [4,5,6]])
print(t)
print(t.T)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 4]
#  [2 5]
#  [3 6]]

# %% [markdown]
# # Statistical function

# %%
a = np.array([[1,2,3],[4,5,6]])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(np.sum(a))
# Out:
# 21

# %%
print(np.mean(a))
print(np.median(a))
print(np.std(a))
print(np.min(a))
print(np.max(a))
# Out:
# 3.5
# 3.5
# 1.707825127659933
# 1
# 6

# %% [markdown]
# # Array Camparision

# %%
a = np.array([1,5,3])
b = np.array([4,5,6])
print(a)
print(b)
# Out:
# [1 5 3]
# [4 5 6]

# %%
print(a == b)
print(np.array_equal(a,b))
# Out:
# [False  True False]
# False

# %% [markdown]
#  # 11 Broadcasting

# %%
a = np.array([1,2,3,5])
b = np.array([5])
print(a+b)
# Out:
# [ 6  7  8 10]

# %%
c = np.array([[1,2,3],[4,5,6]])
d = np.array([10 , 20,30])
print(c+d)
# Out:
# [[11 22 33]
#  [14 25 36]]

# %% [markdown]
# #12  Handling with nan and inf

# %%
data1 = np.array([1,2 ,np.nan,4,np.inf])
print(data1)
# Out:
# [ 1.  2. nan  4. inf]

# %%
print(np.isnan(data1))
# Out:
# [False False  True False False]

# %%
print(np.nan_to_num(data1))
# Out:
# [1.00000000e+000 2.00000000e+000 0.00000000e+000 4.00000000e+000
#  1.79769313e+308]

# %% [markdown]
# #Array Save and Load

# %%
arr = np.array([1,0,0,8])
print(arr)
np.save('my_array.npy',arr)
# Out:
# [1 0 0 8]

# %%
loaded_arr = np.load('my_array.npy')
print(loaded_arr)
# Out:
# [1 0 0 8]
